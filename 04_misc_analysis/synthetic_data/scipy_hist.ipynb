# %%
import scipy.stats
import numpy as np
import matplotlib.pyplot as plt
data = scipy.stats.norm.rvs(size=1000, loc=0, scale=1.5, random_state=123)
hist = np.histogram(data, bins=100)
hist_dist = scipy.stats.rv_histogram(hist)

# %%
x= np.arange(-5,5,0.1)
plt.plot(x,hist_dist.cdf(x))
plt.plot(x,hist_dist.pdf(x))

# %%
import matplotlib.pyplot as plt

X = np.linspace(-5.0, 5.0, 100)

plt.title("PDF from Template")

plt.hist(data, density=True, bins=10)

plt.plot(X, hist_dist.pdf(X), label='PDF')

plt.plot(X, hist_dist.cdf(X), label='CDF')

plt.show()

# %%
import scipy.stats
data = scipy.stats.pearson3.rvs(size=100000, loc=0, scale=1.5,skew = 1)
plt.hist(data)

a,b,c = scipy.stats.pearson3.fit(data)
a,b,c

# cdf = scipy.stats.norm.cdf(data_grid_hist,loc=mu,scale=sig)

# omu,osig = scipy.stats.norm.fit(var_data_obs)

# bias_corr=scipy.stats.norm.ppf(cdf,loc=omu,scale=osig)
# Out:
# (0.9945957167233828, 0.009476109625623622, 1.5029104999208833)

# %%
data = scipy.stats.pareto.rvs(size=10000, loc=0, scale=500,b= 150)
plt.hist(data)

a,b,c = scipy.stats.pareto.fit(data)
a,b,c
# Out:
# (150.05609731021144, -1.1936866623592444, 501.1936969185093)
